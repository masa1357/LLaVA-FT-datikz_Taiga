# %%
import os
import pandas as pd
import numpy as np
from typing import Dict, List
import importlib
from pathlib import Path
import pprint as pp

# %%
import sys

sys.path.append("..")
import importlib

# %%
import src.gradepred_data_forkfold as gradepred_data_forkfold

importlib.reload(gradepred_data_forkfold)
from src.gradepred_data_forkfold import (
    GradePredictionDataset,
    ext_GPDataset,
    GradePredictionCollator,
)

# %%
BASE_PATH = Path.cwd().parent
DATA_PATH = BASE_PATH / "data"
data = GradePredictionDataset(
    dataset_path=DATA_PATH
    )
data.__len__()
# Out:
# 377

# %% [markdown]
# ### datasetの基本動作を確認

# %%
# dataの内容を確認
idx = 31
data.__getitem__(idx)
# Out:
# {'userid': 'C-2021-1_U30',
#  'labels': 0,
#  'grades': 'A',
#  'L1': {'Q1': '情報イントロダクション、情報の大まかな仕組み、情報の歴史',
#   'Q2': '情報は0と1の組み合わせで伝えられていること、モールス信号は作られてから使われるまで時間が空いたこと',
#   'Q3': '特にないです',
#   'Q4': 'NaN',
#   'Q5': 'フランスの腕木通信は知らなかったのでおもしろいと思いました。'},
#  'L2': {'Q1': '情報源とその符号化、望ましい符号',
#   'Q2': '符号は一意に、素早く戻せるもの、短いものが良い。 語頭符号は一意に、瞬時に戻せる。 平均符号語長がエントロピーを下回ることはない。',
#   'Q3': '最適符号の定義',
#   'Q4': '平均符号語長がエントロピーとエントロピーに1を足した値で挟めることは結構すごいことだから、その時の符号を最適符号という、という認識で大丈夫でしょうか。',
#   'Q5': '前回と比べて、一気にハードになったなと感じました。新しい語句がたくさんでてきて混乱しそうです。'},
#  'L3': {'Q1': '情報量、曖昧さの減少、情報の期待値、相互情報量',
#   'Q2': '情報量=曖昧さの減少、起きにくい現象の情報を知った時に得られる情報量は大きい、情報量の期待値はエントロピーに等しい',
#   'Q3': '曖昧さ=log の証明',
#   'Q4': '特にないです',
#   'Q5': 'エントロピーがまだよくわかっていないので、しっかり復習したいです'},
#  'L4': {'Q1': 'ハミング距離、誤り検出と誤り訂正、繰り返し符号、通信路容量',
#   'Q2': '誤り訂正と誤り検出ができる場合について、ハミング距離の求め方、',
#   'Q3': '通信路符号化定理、検査ビット',
#   'Q4': 'NaN',
#   'Q5': 'エントロピーがここでもでできて、重要な存在なのだなと感じました。通信路符号化定理のところと、最後の検査ビットがでてきたところがいまいちよく分からなかったので、ちゃんと復習したいです。'},
#  'L5': {'Q1': 'コンピューターサイエンスとは、計算、アルゴリズム',
#   'Q2': 'アルゴリズムの定義について',
#   'Q3': '根付き木がまだよく分からなかった。',
#   'Q4': 'NaN',
#   'Q5': 'また新しい語句が増えたので、しっかり定着させたいと思いました。コインのアルゴリズムのところが面白かったです。'},
#  'L6': {'Q1': 'バブルソート、選択ソート、2進木ソート、ヒープソート',
#   'Q2': 'それぞれのソートのやり方',
#   'Q3': 'ヒープソートの比較回数にlogが出てくるのがいまいちよくわからないです',
#   'Q4': 'NaN',
#   'Q5': 'ソートがパズルみたいで面白かったです。特に私は2進木ソートが好きです。'},
#  'L7': {'Q1': 'マージソート、二分探索',
#   'Q2': 'マージソートのやり方、二分探索のアルゴリズム',
#   'Q3': 'キーワードの二分探索がちょっと微妙です',
#   'Q4': 'NaN',
#   'Q5': '線形探索と比べて、二分探索の計算量の少なさに驚きました。'},
#  'L8': {'Q1': 'データとは、データの種類、予測、発見、グルーピング',
#   'Q2': 'データ分析は身近であること、データを用いた予測、発見、グルーピングのやり方',
#   'Q3': '特にないです',
#   'Q4': '特にないです',
#   'Q5': 'データ分析はもっと専門的な知識を必要とすると思っていたので、こんなにも身近であることに驚きました。'},
#  'L9': {'Q1': '人工知能とは、人工知能を用いたビジネス、機械学習、今の人工知能にできないこと',
#   'Q2': '人工知能は思っている以上に万能ではないこと、人工知能を利用したビジネスの詳細',
#   'Q3': 'オープン戦略のあたりがまだ曖昧です',
#   'Q4': 'NaN',
#   'Q5': '人間の脳がいかに優れているかを実感しました。また、顧客監視のような人工知能を使ったビジネスの中にも知らないものがあったので、新しい知識を身に着けることができてよかったです。'},
#  'L10': {'Q1': '非構造データ(言語、画像、音声)、パターン認識とその応用',
#   'Q2': '非構造データとは何か、画像はベクトルで表せること、パターン認識とは何か、パターン認識の応用',
#   'Q3': 'とくにないです',
#   'Q4': 'NaN',
#   'Q5': '今、線形代数を履修しているので、ベクトル=画像で気を安らげたいと思います。また、深層ニューラルネットワークによるパターン認識が面白いと思いました。'},
#  'L11': {'Q1': 'データ収集、全数調査、標本調査、個人情報、オープンデータ、著作権',
#   'Q2': 'データ収集の主なやりかた、全数調査と標本調査のメリット・デメリット、個人情報の扱い方',
#   'Q3': 'オープンデータのところがまだ少し微妙です。定義はなんとなく理解できましたが、目的の一つである「透明性、信頼性の向上」がまだよく分からないです。',
#   'Q4': 'NaN',
#   'Q5': '個人情報の部分はサイバーセキュリティでやったところと重なっていたのですぐに理解ができました。また、メディアの街頭インタビューのような標本選択バイアスに惑わされないように気をつけようと思いました。'},
#  'L12': {'Q1': 'ベクトル、距離、類似度、それらの種類や応用',
#   'Q2': 'ベクトルとは何か、ベクトルを用いたデータ分析のやり方、距離の種類、距離や類似度の応用',
#   'Q3': 'max距離の使い方とコサイン類似度が微妙です',
#   'Q4': 'NaN',
#   'Q5': '距離と聞くと長さを表す単位(kmやm)が思いつくが、データ解析においても距離を使うのが新鮮で面白かった。'},
#  'L13': {'Q1': 'データの可視化、そのいろいろなやり方',
#   'Q2': '棒グラフや折れ線グラフなど、データの可視化の手法について、データの可視化の利点',
#   'Q3': '多次元データの可視化',
#   'Q4': 'NaN',
#   'Q5': 'パイチャートやヒートマップなど、初めて知ったデータの表し方があったので、面白かったです。データの可視化をする際には、どのやり方でするのがよいか、だけでなく、軸の数字や点の配置など、考えなければならないことがたくさんあるんだなと感じました。'},
#  'L14': {'Q1': '相関、分散、相関係数、統計的検定、画像処理、フィルタ処理、エッジ抽出',
#   'Q2': '相関係数の求め方、相関や分散や統計的検定の特徴',
#   'Q3': '微分フィルタ、ソーベルフィルタ',
#   'Q4': 'NaN',
#   'Q5': '高校の数学でやったところが多かったので、懐かしい気分になりました。フィルタ処理のところが難しかったです。'},
#  'L15': {'Q1': '画像処理の補足、期末テスト',
#   'Q2': 'ラプラシアンフィルタについて',
#   'Q3': 'NaN',
#   'Q4': 'NaN',
#   'Q5': '期末テストは結構時間がギリギリでした。説明をする記述問題が自信ないです。'}}

# %%
# data.concatの内容を確認
data.concat()
pp.pprint(data.__getitem__(idx))
# Out:
# {'grades': 'A',
#  'input_text': 'L01-Q1: 情報イントロダクション、情報の大まかな仕組み、情報の歴史\n'
#                'L01-Q2: 情報は0と1の組み合わせで伝えられていること、モールス信号は作られてから使われるまで時間が空いたこと\n'
#                'L01-Q3: 特にないです\n'
#                'L01-Q4: NaN\n'
#                'L01-Q5: フランスの腕木通信は知らなかったのでおもしろいと思いました。\n'
#                'L02-Q1: 情報源とその符号化、望ましい符号\n'
#                'L02-Q2: 符号は一意に、素早く戻せるもの、短いものが良い。 語頭符号は一意に、瞬時に戻せる。 '
#                '平均符号語長がエントロピーを下回ることはない。\n'
#                'L02-Q3: 最適符号の定義\n'
#                'L02-Q4: '
#                '平均符号語長がエントロピーとエントロピーに1を足した値で挟めることは結構すごいことだから、その時の符号を最適符号という、という認識で大丈夫でしょうか。\n'
#                'L02-Q5: 前回と比べて、一気にハードになったなと感じました。新しい語句がたくさんでてきて混乱しそうです。\n'
#                'L03-Q1: 情報量、曖昧さの減少、情報の期待値、相互情報量\n'
#                'L03-Q2: '
#                '情報量=曖昧さの減少、起きにくい現象の情報を知った時に得られる情報量は大きい、情報量の期待値はエントロピーに等しい\n'
#                'L03-Q3: 曖昧さ=log の証明\n'
#                'L03-Q4: 特にないです\n'
#                'L03-Q5: エントロピーがまだよくわかっていないので、しっかり復習したいです\n'
#                'L04-Q1: ハミング距離、誤り検出と誤り訂正、繰り返し符号、通信路容量\n'
#                'L04-Q2: 誤り訂正と誤り検出ができる場合について、ハミング距離の求め方、\n'
#                'L04-Q3: 通信路符号化定理、検査ビット\n'
#                'L04-Q4: NaN\n'
#                'L04-Q5: '
#                'エントロピーがここでもでできて、重要な存在なのだなと感じました。通信路符号化定理のところと、最後の検査ビットがでてきたところがいまいちよく分からなかったので、ちゃんと復習したいです。\n'
#                'L05-Q1: コンピューターサイエンスとは、計算、アルゴリズム\n'
#                'L05-Q2: アルゴリズムの定義について\n'
#                'L05-Q3: 根付き木がまだよく分からなかった。\n'
#                'L05-Q4: NaN\n'
#                'L05-Q5: '
#                'また新しい語句が増えたので、しっかり定着させたいと思いました。コインのアルゴリズムのところが面白かったです。\n'
#                'L06-Q1: バブルソート、選択ソート、2進木ソート、ヒープソート\n'
#                'L06-Q2: それぞれのソートのやり方\n'
#                'L06-Q3: ヒープソートの比較回数にlogが出てくるのがいまいちよくわからないです\n'
#                'L06-Q4: NaN\n'
#                'L06-Q5: ソートがパズルみたいで面白かったです。特に私は2進木ソートが好きです。\n'
#                'L07-Q1: マージソート、二分探索\n'
#                'L07-Q2: マージソートのやり方、二分探索のアルゴリズム\n'
#                'L07-Q3: キーワードの二分探索がちょっと微妙です\n'
#                'L07-Q4: NaN\n'
#                'L07-Q5: 線形探索と比べて、二分探索の計算量の少なさに驚きました。\n'
#                'L08-Q1: データとは、データの種類、予測、発見、グルーピング\n'
#                'L08-Q2: データ分析は身近であること、データを用いた予測、発見、グルーピングのやり方\n'
#                'L08-Q3: 特にないです\n'
#                'L08-Q4: 特にないです\n'
#                'L08-Q5: データ分析はもっと専門的な知識を必要とすると思っていたので、こんなにも身近であることに驚きました。\n'
#                'L09-Q1: 人工知能とは、人工知能を用いたビジネス、機械学習、今の人工知能にできないこと\n'
#                'L09-Q2: 人工知能は思っている以上に万能ではないこと、人工知能を利用したビジネスの詳細\n'
#                'L09-Q3: オープン戦略のあたりがまだ曖昧です\n'
#                'L09-Q4: NaN\n'
#                'L09-Q5: '
#                '人間の脳がいかに優れているかを実感しました。また、顧客監視のような人工知能を使ったビジネスの中にも知らないものがあったので、新しい知識を身に着けることができてよかったです。\n'
#                'L10-Q1: 非構造データ(言語、画像、音声)、パターン認識とその応用\n'
#                'L10-Q2: 非構造データとは何か、画像はベクトルで表せること、パターン認識とは何か、パターン認識の応用\n'
#                'L10-Q3: とくにないです\n'
#                'L10-Q4: NaN\n'
#                'L10-Q5: '
#                '今、線形代数を履修しているので、ベクトル=画像で気を安らげたいと思います。また、深層ニューラルネットワークによるパターン認識が面白いと思いました。\n'
#                'L11-Q1: データ収集、全数調査、標本調査、個人情報、オープンデータ、著作権\n'
#                'L11-Q2: データ収集の主なやりかた、全数調査と標本調査のメリット・デメリット、個人情報の扱い方\n'
#                'L11-Q3: '
#                'オープンデータのところがまだ少し微妙です。定義はなんとなく理解できましたが、目的の一つである「透明性、信頼性の向上」がまだよく分からないです。\n'
#                'L11-Q4: NaN\n'
#                'L11-Q5: '
#                '個人情報の部分はサイバーセキュリティでやったところと重なっていたのですぐに理解ができました。また、メディアの街頭インタビューのような標本選択バイアスに惑わされないように気をつけようと思いました。\n'
#                'L12-Q1: ベクトル、距離、類似度、それらの種類や応用\n'
#                'L12-Q2: ベクトルとは何か、ベクトルを用いたデータ分析のやり方、距離の種類、距離や類似度の応用\n'
#                'L12-Q3: max距離の使い方とコサイン類似度が微妙です\n'
#                'L12-Q4: NaN\n'
#                'L12-Q5: 距離と聞くと長さを表す単位(kmやm)が思いつくが、データ解析においても距離を使うのが新鮮で面白かった。\n'
#                'L13-Q1: データの可視化、そのいろいろなやり方\n'
#                'L13-Q2: 棒グラフや折れ線グラフなど、データの可視化の手法について、データの可視化の利点\n'
#                'L13-Q3: 多次元データの可視化\n'
#                'L13-Q4: NaN\n'
#                'L13-Q5: '
#                'パイチャートやヒートマップなど、初めて知ったデータの表し方があったので、面白かったです。データの可視化をする際には、どのやり方でするのがよいか、だけでなく、軸の数字や点の配置など、考えなければならないことがたくさんあるんだなと感じました。\n'
#                'L14-Q1: 相関、分散、相関係数、統計的検定、画像処理、フィルタ処理、エッジ抽出\n'
#                'L14-Q2: 相関係数の求め方、相関や分散や統計的検定の特徴\n'
#                'L14-Q3: 微分フィルタ、ソーベルフィルタ\n'
#                'L14-Q4: NaN\n'
#                'L14-Q5: 高校の数学でやったところが多かったので、懐かしい気分になりました。フィルタ処理のところが難しかったです。\n'
#                'L15-Q1: 画像処理の補足、期末テスト\n'
#                'L15-Q2: ラプラシアンフィルタについて\n'
#                'L15-Q3: NaN\n'
#                'L15-Q4: NaN\n'
#                'L15-Q5: 期末テストは結構時間がギリギリでした。説明をする記述問題が自信ないです。',
#  'labels': 0,
#  'userid': 'C-2021-1_U30'}

# %%
# data.unzipの内容を確認
data.unzip()
pp.pprint(data.__len__())
pp.pprint(data.__getitem__(idx))
# Out:
# 28275
# {'grades': 'F',
#  'input_text': 'L7-Q2: '
#                'ヒープソートと二部探索はだいたいの仕組みを理解することができた。計算も、考えてみればよく分かるものが多く、復習すればより定着させることが出来ると思う。',
#  'labels': 4,
#  'userid': 'C-2021-1_U1'}

# %%
# データ拡張が可能か確認
data.extention()
data.__len__()
# Out:
# 58275

# %%
# resetの動作を確認
data.reset()
pp.pprint(data.__len__)
pp.pprint(data.__getitem__(idx))
# Out:
# <bound method GradePredictionDataset.__len__ of <src.gradepred_data_forkfold.GradePredictionDataset object at 0x7f08e2ba8430>>
# {'L1': {'Q1': '情報イントロダクション、情報の大まかな仕組み、情報の歴史',
#         'Q2': '情報は0と1の組み合わせで伝えられていること、モールス信号は作られてから使われるまで時間が空いたこと',
#         'Q3': '特にないです',
#         'Q4': 'NaN',
#         'Q5': 'フランスの腕木通信は知らなかったのでおもしろいと思いました。'},
#  'L10': {'Q1': '非構造データ(言語、画像、音声)、パターン認識とその応用',
#          'Q2': '非構造データとは何か、画像はベクトルで表せること、パターン認識とは何か、パターン認識の応用',
#          'Q3': 'とくにないです',
#          'Q4': 'NaN',
#          'Q5': '今、線形代数を履修しているので、ベクトル=画像で気を安らげたいと思います。また、深層ニューラルネットワークによるパターン認識が面白いと思いました。'},
#  'L11': {'Q1': 'データ収集、全数調査、標本調査、個人情報、オープンデータ、著作権',
#          'Q2': 'データ収集の主なやりかた、全数調査と標本調査のメリット・デメリット、個人情報の扱い方',
#          'Q3': 'オープンデータのところがまだ少し微妙です。定義はなんとなく理解できましたが、目的の一つである「透明性、信頼性の向上」がまだよく分からないです。',
#          'Q4': 'NaN',
#          'Q5': '個人情報の部分はサイバーセキュリティでやったところと重なっていたのですぐに理解ができました。また、メディアの街頭インタビューのような標本選択バイアスに惑わされないように気をつけようと思いました。'},
#  'L12': {'Q1': 'ベクトル、距離、類似度、それらの種類や応用',
#          'Q2': 'ベクトルとは何か、ベクトルを用いたデータ分析のやり方、距離の種類、距離や類似度の応用',
#          'Q3': 'max距離の使い方とコサイン類似度が微妙です',
#          'Q4': 'NaN',
#          'Q5': '距離と聞くと長さを表す単位(kmやm)が思いつくが、データ解析においても距離を使うのが新鮮で面白かった。'},
#  'L13': {'Q1': 'データの可視化、そのいろいろなやり方',
#          'Q2': '棒グラフや折れ線グラフなど、データの可視化の手法について、データの可視化の利点',
#          'Q3': '多次元データの可視化',
#          'Q4': 'NaN',
#          'Q5': 'パイチャートやヒートマップなど、初めて知ったデータの表し方があったので、面白かったです。データの可視化をする際には、どのやり方でするのがよいか、だけでなく、軸の数字や点の配置など、考えなければならないことがたくさんあるんだなと感じました。'},
#  'L14': {'Q1': '相関、分散、相関係数、統計的検定、画像処理、フィルタ処理、エッジ抽出',
#          'Q2': '相関係数の求め方、相関や分散や統計的検定の特徴',
#          'Q3': '微分フィルタ、ソーベルフィルタ',
#          'Q4': 'NaN',
#          'Q5': '高校の数学でやったところが多かったので、懐かしい気分になりました。フィルタ処理のところが難しかったです。'},
#  'L15': {'Q1': '画像処理の補足、期末テスト',
#          'Q2': 'ラプラシアンフィルタについて',
#          'Q3': 'NaN',
#          'Q4': 'NaN',
#          'Q5': '期末テストは結構時間がギリギリでした。説明をする記述問題が自信ないです。'},
#  'L2': {'Q1': '情報源とその符号化、望ましい符号',
#         'Q2': '符号は一意に、素早く戻せるもの、短いものが良い。 語頭符号は一意に、瞬時に戻せる。 '
#               '平均符号語長がエントロピーを下回ることはない。',
#         'Q3': '最適符号の定義',
#         'Q4': '平均符号語長がエントロピーとエントロピーに1を足した値で挟めることは結構すごいことだから、その時の符号を最適符号という、という認識で大丈夫でしょうか。',
#         'Q5': '前回と比べて、一気にハードになったなと感じました。新しい語句がたくさんでてきて混乱しそうです。'},
#  'L3': {'Q1': '情報量、曖昧さの減少、情報の期待値、相互情報量',
#         'Q2': '情報量=曖昧さの減少、起きにくい現象の情報を知った時に得られる情報量は大きい、情報量の期待値はエントロピーに等しい',
#         'Q3': '曖昧さ=log の証明',
#         'Q4': '特にないです',
#         'Q5': 'エントロピーがまだよくわかっていないので、しっかり復習したいです'},
#  'L4': {'Q1': 'ハミング距離、誤り検出と誤り訂正、繰り返し符号、通信路容量',
#         'Q2': '誤り訂正と誤り検出ができる場合について、ハミング距離の求め方、',
#         'Q3': '通信路符号化定理、検査ビット',
#         'Q4': 'NaN',
#         'Q5': 'エントロピーがここでもでできて、重要な存在なのだなと感じました。通信路符号化定理のところと、最後の検査ビットがでてきたところがいまいちよく分からなかったので、ちゃんと復習したいです。'},
#  'L5': {'Q1': 'コンピューターサイエンスとは、計算、アルゴリズム',
#         'Q2': 'アルゴリズムの定義について',
#         'Q3': '根付き木がまだよく分からなかった。',
#         'Q4': 'NaN',
#         'Q5': 'また新しい語句が増えたので、しっかり定着させたいと思いました。コインのアルゴリズムのところが面白かったです。'},
#  'L6': {'Q1': 'バブルソート、選択ソート、2進木ソート、ヒープソート',
#         'Q2': 'それぞれのソートのやり方',
#         'Q3': 'ヒープソートの比較回数にlogが出てくるのがいまいちよくわからないです',
#         'Q4': 'NaN',
#         'Q5': 'ソートがパズルみたいで面白かったです。特に私は2進木ソートが好きです。'},
#  'L7': {'Q1': 'マージソート、二分探索',
#         'Q2': 'マージソートのやり方、二分探索のアルゴリズム',
#         'Q3': 'キーワードの二分探索がちょっと微妙です',
#         'Q4': 'NaN',
#         'Q5': '線形探索と比べて、二分探索の計算量の少なさに驚きました。'},
#  'L8': {'Q1': 'データとは、データの種類、予測、発見、グルーピング',
#         'Q2': 'データ分析は身近であること、データを用いた予測、発見、グルーピングのやり方',
#         'Q3': '特にないです',
#         'Q4': '特にないです',
#         'Q5': 'データ分析はもっと専門的な知識を必要とすると思っていたので、こんなにも身近であることに驚きました。'},
#  'L9': {'Q1': '人工知能とは、人工知能を用いたビジネス、機械学習、今の人工知能にできないこと',
#         'Q2': '人工知能は思っている以上に万能ではないこと、人工知能を利用したビジネスの詳細',
#         'Q3': 'オープン戦略のあたりがまだ曖昧です',
#         'Q4': 'NaN',
#         'Q5': '人間の脳がいかに優れているかを実感しました。また、顧客監視のような人工知能を使ったビジネスの中にも知らないものがあったので、新しい知識を身に着けることができてよかったです。'},
#  'grades': 'A',
#  'input_text': 'L1-Q1: 情報イントロダクション、情報の大まかな仕組み、情報の歴史\n'
#                'L1-Q2: 情報は0と1の組み合わせで伝えられていること、モールス信号は作られてから使われるまで時間が空いたこと\n'
#                'L1-Q3: 特にないです\n'
#                'L1-Q4: NaN\n'
#                'L1-Q5: フランスの腕木通信は知らなかったのでおもしろいと思いました。\n'
#                'L2-Q1: 情報源とその符号化、望ましい符号\n'
#                'L2-Q2: 符号は一意に、素早く戻せるもの、短いものが良い。 語頭符号は一意に、瞬時に戻せる。 '
#                '平均符号語長がエントロピーを下回ることはない。\n'
#                'L2-Q3: 最適符号の定義\n'
#                'L2-Q4: '
#                '平均符号語長がエントロピーとエントロピーに1を足した値で挟めることは結構すごいことだから、その時の符号を最適符号という、という認識で大丈夫でしょうか。\n'
#                'L2-Q5: 前回と比べて、一気にハードになったなと感じました。新しい語句がたくさんでてきて混乱しそうです。\n'
#                'L3-Q1: 情報量、曖昧さの減少、情報の期待値、相互情報量\n'
#                'L3-Q2: '
#                '情報量=曖昧さの減少、起きにくい現象の情報を知った時に得られる情報量は大きい、情報量の期待値はエントロピーに等しい\n'
#                'L3-Q3: 曖昧さ=log の証明\n'
#                'L3-Q4: 特にないです\n'
#                'L3-Q5: エントロピーがまだよくわかっていないので、しっかり復習したいです\n'
#                'L4-Q1: ハミング距離、誤り検出と誤り訂正、繰り返し符号、通信路容量\n'
#                'L4-Q2: 誤り訂正と誤り検出ができる場合について、ハミング距離の求め方、\n'
#                'L4-Q3: 通信路符号化定理、検査ビット\n'
#                'L4-Q4: NaN\n'
#                'L4-Q5: '
#                'エントロピーがここでもでできて、重要な存在なのだなと感じました。通信路符号化定理のところと、最後の検査ビットがでてきたところがいまいちよく分からなかったので、ちゃんと復習したいです。\n'
#                'L5-Q1: コンピューターサイエンスとは、計算、アルゴリズム\n'
#                'L5-Q2: アルゴリズムの定義について\n'
#                'L5-Q3: 根付き木がまだよく分からなかった。\n'
#                'L5-Q4: NaN\n'
#                'L5-Q5: また新しい語句が増えたので、しっかり定着させたいと思いました。コインのアルゴリズムのところが面白かったです。\n'
#                'L6-Q1: バブルソート、選択ソート、2進木ソート、ヒープソート\n'
#                'L6-Q2: それぞれのソートのやり方\n'
#                'L6-Q3: ヒープソートの比較回数にlogが出てくるのがいまいちよくわからないです\n'
#                'L6-Q4: NaN\n'
#                'L6-Q5: ソートがパズルみたいで面白かったです。特に私は2進木ソートが好きです。\n'
#                'L7-Q1: マージソート、二分探索\n'
#                'L7-Q2: マージソートのやり方、二分探索のアルゴリズム\n'
#                'L7-Q3: キーワードの二分探索がちょっと微妙です\n'
#                'L7-Q4: NaN\n'
#                'L7-Q5: 線形探索と比べて、二分探索の計算量の少なさに驚きました。\n'
#                'L8-Q1: データとは、データの種類、予測、発見、グルーピング\n'
#                'L8-Q2: データ分析は身近であること、データを用いた予測、発見、グルーピングのやり方\n'
#                'L8-Q3: 特にないです\n'
#                'L8-Q4: 特にないです\n'
#                'L8-Q5: データ分析はもっと専門的な知識を必要とすると思っていたので、こんなにも身近であることに驚きました。\n'
#                'L9-Q1: 人工知能とは、人工知能を用いたビジネス、機械学習、今の人工知能にできないこと\n'
#                'L9-Q2: 人工知能は思っている以上に万能ではないこと、人工知能を利用したビジネスの詳細\n'
#                'L9-Q3: オープン戦略のあたりがまだ曖昧です\n'
#                'L9-Q4: NaN\n'
#                'L9-Q5: '
#                '人間の脳がいかに優れているかを実感しました。また、顧客監視のような人工知能を使ったビジネスの中にも知らないものがあったので、新しい知識を身に着けることができてよかったです。\n'
#                'L10-Q1: 非構造データ(言語、画像、音声)、パターン認識とその応用\n'
#                'L10-Q2: 非構造データとは何か、画像はベクトルで表せること、パターン認識とは何か、パターン認識の応用\n'
#                'L10-Q3: とくにないです\n'
#                'L10-Q4: NaN\n'
#                'L10-Q5: '
#                '今、線形代数を履修しているので、ベクトル=画像で気を安らげたいと思います。また、深層ニューラルネットワークによるパターン認識が面白いと思いました。\n'
#                'L11-Q1: データ収集、全数調査、標本調査、個人情報、オープンデータ、著作権\n'
#                'L11-Q2: データ収集の主なやりかた、全数調査と標本調査のメリット・デメリット、個人情報の扱い方\n'
#                'L11-Q3: '
#                'オープンデータのところがまだ少し微妙です。定義はなんとなく理解できましたが、目的の一つである「透明性、信頼性の向上」がまだよく分からないです。\n'
#                'L11-Q4: NaN\n'
#                'L11-Q5: '
#                '個人情報の部分はサイバーセキュリティでやったところと重なっていたのですぐに理解ができました。また、メディアの街頭インタビューのような標本選択バイアスに惑わされないように気をつけようと思いました。\n'
#                'L12-Q1: ベクトル、距離、類似度、それらの種類や応用\n'
#                'L12-Q2: ベクトルとは何か、ベクトルを用いたデータ分析のやり方、距離の種類、距離や類似度の応用\n'
#                'L12-Q3: max距離の使い方とコサイン類似度が微妙です\n'
#                'L12-Q4: NaN\n'
#                'L12-Q5: 距離と聞くと長さを表す単位(kmやm)が思いつくが、データ解析においても距離を使うのが新鮮で面白かった。\n'
#                'L13-Q1: データの可視化、そのいろいろなやり方\n'
#                'L13-Q2: 棒グラフや折れ線グラフなど、データの可視化の手法について、データの可視化の利点\n'
#                'L13-Q3: 多次元データの可視化\n'
#                'L13-Q4: NaN\n'
#                'L13-Q5: '
#                'パイチャートやヒートマップなど、初めて知ったデータの表し方があったので、面白かったです。データの可視化をする際には、どのやり方でするのがよいか、だけでなく、軸の数字や点の配置など、考えなければならないことがたくさんあるんだなと感じました。\n'
#                'L14-Q1: 相関、分散、相関係数、統計的検定、画像処理、フィルタ処理、エッジ抽出\n'
#                'L14-Q2: 相関係数の求め方、相関や分散や統計的検定の特徴\n'
#                'L14-Q3: 微分フィルタ、ソーベルフィルタ\n'
#                'L14-Q4: NaN\n'
#                'L14-Q5: 高校の数学でやったところが多かったので、懐かしい気分になりました。フィルタ処理のところが難しかったです。\n'
#                'L15-Q1: 画像処理の補足、期末テスト\n'
#                'L15-Q2: ラプラシアンフィルタについて\n'
#                'L15-Q3: NaN\n'
#                'L15-Q4: NaN\n'
#                'L15-Q5: 期末テストは結構時間がギリギリでした。説明をする記述問題が自信ないです。',
#  'labels': 0,
#  'userid': 'C-2021-1_U30'}

# %%
# reset後のdata.concatの内容を確認
data.concat()
pp.pprint(data.__getitem__(idx))
data.reset()
# Out:
# {'grades': 'A',
#  'input_text': 'L01-Q1: 情報イントロダクション、情報の大まかな仕組み、情報の歴史\n'
#                'L01-Q2: 情報は0と1の組み合わせで伝えられていること、モールス信号は作られてから使われるまで時間が空いたこと\n'
#                'L01-Q3: 特にないです\n'
#                'L01-Q4: NaN\n'
#                'L01-Q5: フランスの腕木通信は知らなかったのでおもしろいと思いました。\n'
#                'L02-Q1: 情報源とその符号化、望ましい符号\n'
#                'L02-Q2: 符号は一意に、素早く戻せるもの、短いものが良い。 語頭符号は一意に、瞬時に戻せる。 '
#                '平均符号語長がエントロピーを下回ることはない。\n'
#                'L02-Q3: 最適符号の定義\n'
#                'L02-Q4: '
#                '平均符号語長がエントロピーとエントロピーに1を足した値で挟めることは結構すごいことだから、その時の符号を最適符号という、という認識で大丈夫でしょうか。\n'
#                'L02-Q5: 前回と比べて、一気にハードになったなと感じました。新しい語句がたくさんでてきて混乱しそうです。\n'
#                'L03-Q1: 情報量、曖昧さの減少、情報の期待値、相互情報量\n'
#                'L03-Q2: '
#                '情報量=曖昧さの減少、起きにくい現象の情報を知った時に得られる情報量は大きい、情報量の期待値はエントロピーに等しい\n'
#                'L03-Q3: 曖昧さ=log の証明\n'
#                'L03-Q4: 特にないです\n'
#                'L03-Q5: エントロピーがまだよくわかっていないので、しっかり復習したいです\n'
#                'L04-Q1: ハミング距離、誤り検出と誤り訂正、繰り返し符号、通信路容量\n'
#                'L04-Q2: 誤り訂正と誤り検出ができる場合について、ハミング距離の求め方、\n'
#                'L04-Q3: 通信路符号化定理、検査ビット\n'
#                'L04-Q4: NaN\n'
#                'L04-Q5: '
#                'エントロピーがここでもでできて、重要な存在なのだなと感じました。通信路符号化定理のところと、最後の検査ビットがでてきたところがいまいちよく分からなかったので、ちゃんと復習したいです。\n'
#                'L05-Q1: コンピューターサイエンスとは、計算、アルゴリズム\n'
#                'L05-Q2: アルゴリズムの定義について\n'
#                'L05-Q3: 根付き木がまだよく分からなかった。\n'
#                'L05-Q4: NaN\n'
#                'L05-Q5: '
#                'また新しい語句が増えたので、しっかり定着させたいと思いました。コインのアルゴリズムのところが面白かったです。\n'
#                'L06-Q1: バブルソート、選択ソート、2進木ソート、ヒープソート\n'
#                'L06-Q2: それぞれのソートのやり方\n'
#                'L06-Q3: ヒープソートの比較回数にlogが出てくるのがいまいちよくわからないです\n'
#                'L06-Q4: NaN\n'
#                'L06-Q5: ソートがパズルみたいで面白かったです。特に私は2進木ソートが好きです。\n'
#                'L07-Q1: マージソート、二分探索\n'
#                'L07-Q2: マージソートのやり方、二分探索のアルゴリズム\n'
#                'L07-Q3: キーワードの二分探索がちょっと微妙です\n'
#                'L07-Q4: NaN\n'
#                'L07-Q5: 線形探索と比べて、二分探索の計算量の少なさに驚きました。\n'
#                'L08-Q1: データとは、データの種類、予測、発見、グルーピング\n'
#                'L08-Q2: データ分析は身近であること、データを用いた予測、発見、グルーピングのやり方\n'
#                'L08-Q3: 特にないです\n'
#                'L08-Q4: 特にないです\n'
#                'L08-Q5: データ分析はもっと専門的な知識を必要とすると思っていたので、こんなにも身近であることに驚きました。\n'
#                'L09-Q1: 人工知能とは、人工知能を用いたビジネス、機械学習、今の人工知能にできないこと\n'
#                'L09-Q2: 人工知能は思っている以上に万能ではないこと、人工知能を利用したビジネスの詳細\n'
#                'L09-Q3: オープン戦略のあたりがまだ曖昧です\n'
#                'L09-Q4: NaN\n'
#                'L09-Q5: '
#                '人間の脳がいかに優れているかを実感しました。また、顧客監視のような人工知能を使ったビジネスの中にも知らないものがあったので、新しい知識を身に着けることができてよかったです。\n'
#                'L10-Q1: 非構造データ(言語、画像、音声)、パターン認識とその応用\n'
#                'L10-Q2: 非構造データとは何か、画像はベクトルで表せること、パターン認識とは何か、パターン認識の応用\n'
#                'L10-Q3: とくにないです\n'
#                'L10-Q4: NaN\n'
#                'L10-Q5: '
#                '今、線形代数を履修しているので、ベクトル=画像で気を安らげたいと思います。また、深層ニューラルネットワークによるパターン認識が面白いと思いました。\n'
#                'L11-Q1: データ収集、全数調査、標本調査、個人情報、オープンデータ、著作権\n'
#                'L11-Q2: データ収集の主なやりかた、全数調査と標本調査のメリット・デメリット、個人情報の扱い方\n'
#                'L11-Q3: '
#                'オープンデータのところがまだ少し微妙です。定義はなんとなく理解できましたが、目的の一つである「透明性、信頼性の向上」がまだよく分からないです。\n'
#                'L11-Q4: NaN\n'
#                'L11-Q5: '
#                '個人情報の部分はサイバーセキュリティでやったところと重なっていたのですぐに理解ができました。また、メディアの街頭インタビューのような標本選択バイアスに惑わされないように気をつけようと思いました。\n'
#                'L12-Q1: ベクトル、距離、類似度、それらの種類や応用\n'
#                'L12-Q2: ベクトルとは何か、ベクトルを用いたデータ分析のやり方、距離の種類、距離や類似度の応用\n'
#                'L12-Q3: max距離の使い方とコサイン類似度が微妙です\n'
#                'L12-Q4: NaN\n'
#                'L12-Q5: 距離と聞くと長さを表す単位(kmやm)が思いつくが、データ解析においても距離を使うのが新鮮で面白かった。\n'
#                'L13-Q1: データの可視化、そのいろいろなやり方\n'
#                'L13-Q2: 棒グラフや折れ線グラフなど、データの可視化の手法について、データの可視化の利点\n'
#                'L13-Q3: 多次元データの可視化\n'
#                'L13-Q4: NaN\n'
#                'L13-Q5: '
#                'パイチャートやヒートマップなど、初めて知ったデータの表し方があったので、面白かったです。データの可視化をする際には、どのやり方でするのがよいか、だけでなく、軸の数字や点の配置など、考えなければならないことがたくさんあるんだなと感じました。\n'
#                'L14-Q1: 相関、分散、相関係数、統計的検定、画像処理、フィルタ処理、エッジ抽出\n'
#                'L14-Q2: 相関係数の求め方、相関や分散や統計的検定の特徴\n'
#                'L14-Q3: 微分フィルタ、ソーベルフィルタ\n'
#                'L14-Q4: NaN\n'
#                'L14-Q5: 高校の数学でやったところが多かったので、懐かしい気分になりました。フィルタ処理のところが難しかったです。\n'
#                'L15-Q1: 画像処理の補足、期末テスト\n'
#                'L15-Q2: ラプラシアンフィルタについて\n'
#                'L15-Q3: NaN\n'
#                'L15-Q4: NaN\n'
#                'L15-Q5: 期末テストは結構時間がギリギリでした。説明をする記述問題が自信ないです。',
#  'labels': 0,
#  'userid': 'C-2021-1_U30'}

# %% [markdown]
# ### k-fold時の挙動を確認

# %%
from sklearn.model_selection import GroupKFold
from torch.utils.data import Subset, ConcatDataset, DataLoader

# %%
import src.plotlylayout as pl
import plotly.graph_objects as go
pl.dark_mode()

def plot_fold_split_plotly(n_samples, train_idx, valid_idx, title=None):
    import plotly.graph_objects as go

    fig = go.Figure().update_layout(
        margin=dict(l=10, r=10, t=20, b=50)
    )
    fig.add_trace(go.Scatter(
        x=train_idx, y=[0]*len(train_idx),
        mode="markers",
        marker=dict(symbol="line-ns-open", size=18),
        name="train"
    ))
    fig.add_trace(go.Scatter(
        x=valid_idx, y=[0]*len(valid_idx),
        mode="markers",
        marker=dict(symbol="line-ns-open", size=22),
        name="valid"
    ))
    fig.update_layout(
        title=title,
        xaxis_title="sample index",
        yaxis=dict(showticklabels=False, showgrid=False, zeroline=False),
        height=200,
        legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1)
    )
    return fig

# %%
# 15 * 5データの場合
data.concat()
groups = np.array([data[i]["userid"] for i in range(len(data))])
print(len(groups))
gkf = GroupKFold(n_splits=5)
# Out:
# 377

# %%
data.__getitem__(idx)
# Out:
# {'userid': 'C-2021-1_U30',
#  'labels': 0,
#  'grades': 'A',
#  'input_text': 'L01-Q1: 情報イントロダクション、情報の大まかな仕組み、情報の歴史\nL01-Q2: 情報は0と1の組み合わせで伝えられていること、モールス信号は作られてから使われるまで時間が空いたこと\nL01-Q3: 特にないです\nL01-Q4: NaN\nL01-Q5: フランスの腕木通信は知らなかったのでおもしろいと思いました。\nL02-Q1: 情報源とその符号化、望ましい符号\nL02-Q2: 符号は一意に、素早く戻せるもの、短いものが良い。 語頭符号は一意に、瞬時に戻せる。 平均符号語長がエントロピーを下回ることはない。\nL02-Q3: 最適符号の定義\nL02-Q4: 平均符号語長がエントロピーとエントロピーに1を足した値で挟めることは結構すごいことだから、その時の符号を最適符号という、という認識で大丈夫でしょうか。\nL02-Q5: 前回と比べて、一気にハードになったなと感じました。新しい語句がたくさんでてきて混乱しそうです。\nL03-Q1: 情報量、曖昧さの減少、情報の期待値、相互情報量\nL03-Q2: 情報量=曖昧さの減少、起きにくい現象の情報を知った時に得られる情報量は大きい、情報量の期待値はエントロピーに等しい\nL03-Q3: 曖昧さ=log の証明\nL03-Q4: 特にないです\nL03-Q5: エントロピーがまだよくわかっていないので、しっかり復習したいです\nL04-Q1: ハミング距離、誤り検出と誤り訂正、繰り返し符号、通信路容量\nL04-Q2: 誤り訂正と誤り検出ができる場合について、ハミング距離の求め方、\nL04-Q3: 通信路符号化定理、検査ビット\nL04-Q4: NaN\nL04-Q5: エントロピーがここでもでできて、重要な存在なのだなと感じました。通信路符号化定理のところと、最後の検査ビットがでてきたところがいまいちよく分からなかったので、ちゃんと復習したいです。\nL05-Q1: コンピューターサイエンスとは、計算、アルゴリズム\nL05-Q2: アルゴリズムの定義について\nL05-Q3: 根付き木がまだよく分からなかった。\nL05-Q4: NaN\nL05-Q5: また新しい語句が増えたので、しっかり定着させたいと思いました。コインのアルゴリズムのところが面白かったです。\nL06-Q1: バブルソート、選択ソート、2進木ソート、ヒープソート\nL06-Q2: それぞれのソートのやり方\nL06-Q3: ヒープソートの比較回数にlogが出てくるのがいまいちよくわからないです\nL06-Q4: NaN\nL06-Q5: ソートがパズルみたいで面白かったです。特に私は2進木ソートが好きです。\nL07-Q1: マージソート、二分探索\nL07-Q2: マージソートのやり方、二分探索のアルゴリズム\nL07-Q3: キーワードの二分探索がちょっと微妙です\nL07-Q4: NaN\nL07-Q5: 線形探索と比べて、二分探索の計算量の少なさに驚きました。\nL08-Q1: データとは、データの種類、予測、発見、グルーピング\nL08-Q2: データ分析は身近であること、データを用いた予測、発見、グルーピングのやり方\nL08-Q3: 特にないです\nL08-Q4: 特にないです\nL08-Q5: データ分析はもっと専門的な知識を必要とすると思っていたので、こんなにも身近であることに驚きました。\nL09-Q1: 人工知能とは、人工知能を用いたビジネス、機械学習、今の人工知能にできないこと\nL09-Q2: 人工知能は思っている以上に万能ではないこと、人工知能を利用したビジネスの詳細\nL09-Q3: オープン戦略のあたりがまだ曖昧です\nL09-Q4: NaN\nL09-Q5: 人間の脳がいかに優れているかを実感しました。また、顧客監視のような人工知能を使ったビジネスの中にも知らないものがあったので、新しい知識を身に着けることができてよかったです。\nL10-Q1: 非構造データ(言語、画像、音声)、パターン認識とその応用\nL10-Q2: 非構造データとは何か、画像はベクトルで表せること、パターン認識とは何か、パターン認識の応用\nL10-Q3: とくにないです\nL10-Q4: NaN\nL10-Q5: 今、線形代数を履修しているので、ベクトル=画像で気を安らげたいと思います。また、深層ニューラルネットワークによるパターン認識が面白いと思いました。\nL11-Q1: データ収集、全数調査、標本調査、個人情報、オープンデータ、著作権\nL11-Q2: データ収集の主なやりかた、全数調査と標本調査のメリット・デメリット、個人情報の扱い方\nL11-Q3: オープンデータのところがまだ少し微妙です。定義はなんとなく理解できましたが、目的の一つである「透明性、信頼性の向上」がまだよく分からないです。\nL11-Q4: NaN\nL11-Q5: 個人情報の部分はサイバーセキュリティでやったところと重なっていたのですぐに理解ができました。また、メディアの街頭インタビューのような標本選択バイアスに惑わされないように気をつけようと思いました。\nL12-Q1: ベクトル、距離、類似度、それらの種類や応用\nL12-Q2: ベクトルとは何か、ベクトルを用いたデータ分析のやり方、距離の種類、距離や類似度の応用\nL12-Q3: max距離の使い方とコサイン類似度が微妙です\nL12-Q4: NaN\nL12-Q5: 距離と聞くと長さを表す単位(kmやm)が思いつくが、データ解析においても距離を使うのが新鮮で面白かった。\nL13-Q1: データの可視化、そのいろいろなやり方\nL13-Q2: 棒グラフや折れ線グラフなど、データの可視化の手法について、データの可視化の利点\nL13-Q3: 多次元データの可視化\nL13-Q4: NaN\nL13-Q5: パイチャートやヒートマップなど、初めて知ったデータの表し方があったので、面白かったです。データの可視化をする際には、どのやり方でするのがよいか、だけでなく、軸の数字や点の配置など、考えなければならないことがたくさんあるんだなと感じました。\nL14-Q1: 相関、分散、相関係数、統計的検定、画像処理、フィルタ処理、エッジ抽出\nL14-Q2: 相関係数の求め方、相関や分散や統計的検定の特徴\nL14-Q3: 微分フィルタ、ソーベルフィルタ\nL14-Q4: NaN\nL14-Q5: 高校の数学でやったところが多かったので、懐かしい気分になりました。フィルタ処理のところが難しかったです。\nL15-Q1: 画像処理の補足、期末テスト\nL15-Q2: ラプラシアンフィルタについて\nL15-Q3: NaN\nL15-Q4: NaN\nL15-Q5: 期末テストは結構時間がギリギリでした。説明をする記述問題が自信ないです。'}

# %%
# tokenizerのロード
from transformers import AutoTokenizer

base_model = "elyza/Llama-3-ELYZA-JP-8B"
tokenizer = AutoTokenizer.from_pretrained(
    base_model, use_fast=True  # padding_side="left"
)

# %%
ans = "今日はいい天気！"
tokens = tokenizer.encode(ans, add_special_tokens=False, truncation=False)
print(tokens)
dec = tokenizer.decode(tokens, skip_special_tokens=True)
print(dec)
# Out:
# [110589, 15682, 104712, 36827, 95221, 6447]
# 今日はいい天気！

# %%
from logging import Logger, INFO, DEBUG
from src.util import set_logger

logger = set_logger(level=INFO)
# Out:
# 2025-07-18 15:34:40,025 : src.util : INFO : 58 : Test_message

# %%
print("collator sample::")
train_collator = GradePredictionCollator(
    tokenizer,
    max_tokens=3072,
    include_target=False,
    question_filter=[1],
    logger = logger,
)
# Out:
# 2025-07-18 15:34:40,031 : src.util : INFO : 537 : Questions: [1], Q1:今日の内容を自分なりの言葉で説明してみてください
#
# 2025-07-18 15:34:40,033 : src.util : INFO : 551 : preamble set:
# ================
# あなたは大学の教授であり、学生の成績を決定する役割を担っています。以下に示す学生の講義後アンケートを読み、成績を高い順に A、B、C、D、F のいずれかに分類してください。
# 成績は出力例のような形式で出力してください。
# 入力文のL は講義回、Q は質問番号を示します（例: L1-Q1）。
# アンケートの質問文は、
# Q1:今日の内容を自分なりの言葉で説明してみてください
# です。回答が NaN の場合は未回答です。
# 出力には A、B、C、D、F のいずれかを含めてください。
# 出力例:
# この学生の成績は、Aです。
# アンケート内容：
# ================
# collator sample::

# %%
data.__getitem__(idx)
# Out:
# {'userid': 'C-2021-1_U30',
#  'labels': 0,
#  'grades': 'A',
#  'input_text': 'L01-Q1: 情報イントロダクション、情報の大まかな仕組み、情報の歴史\nL01-Q2: 情報は0と1の組み合わせで伝えられていること、モールス信号は作られてから使われるまで時間が空いたこと\nL01-Q3: 特にないです\nL01-Q4: NaN\nL01-Q5: フランスの腕木通信は知らなかったのでおもしろいと思いました。\nL02-Q1: 情報源とその符号化、望ましい符号\nL02-Q2: 符号は一意に、素早く戻せるもの、短いものが良い。 語頭符号は一意に、瞬時に戻せる。 平均符号語長がエントロピーを下回ることはない。\nL02-Q3: 最適符号の定義\nL02-Q4: 平均符号語長がエントロピーとエントロピーに1を足した値で挟めることは結構すごいことだから、その時の符号を最適符号という、という認識で大丈夫でしょうか。\nL02-Q5: 前回と比べて、一気にハードになったなと感じました。新しい語句がたくさんでてきて混乱しそうです。\nL03-Q1: 情報量、曖昧さの減少、情報の期待値、相互情報量\nL03-Q2: 情報量=曖昧さの減少、起きにくい現象の情報を知った時に得られる情報量は大きい、情報量の期待値はエントロピーに等しい\nL03-Q3: 曖昧さ=log の証明\nL03-Q4: 特にないです\nL03-Q5: エントロピーがまだよくわかっていないので、しっかり復習したいです\nL04-Q1: ハミング距離、誤り検出と誤り訂正、繰り返し符号、通信路容量\nL04-Q2: 誤り訂正と誤り検出ができる場合について、ハミング距離の求め方、\nL04-Q3: 通信路符号化定理、検査ビット\nL04-Q4: NaN\nL04-Q5: エントロピーがここでもでできて、重要な存在なのだなと感じました。通信路符号化定理のところと、最後の検査ビットがでてきたところがいまいちよく分からなかったので、ちゃんと復習したいです。\nL05-Q1: コンピューターサイエンスとは、計算、アルゴリズム\nL05-Q2: アルゴリズムの定義について\nL05-Q3: 根付き木がまだよく分からなかった。\nL05-Q4: NaN\nL05-Q5: また新しい語句が増えたので、しっかり定着させたいと思いました。コインのアルゴリズムのところが面白かったです。\nL06-Q1: バブルソート、選択ソート、2進木ソート、ヒープソート\nL06-Q2: それぞれのソートのやり方\nL06-Q3: ヒープソートの比較回数にlogが出てくるのがいまいちよくわからないです\nL06-Q4: NaN\nL06-Q5: ソートがパズルみたいで面白かったです。特に私は2進木ソートが好きです。\nL07-Q1: マージソート、二分探索\nL07-Q2: マージソートのやり方、二分探索のアルゴリズム\nL07-Q3: キーワードの二分探索がちょっと微妙です\nL07-Q4: NaN\nL07-Q5: 線形探索と比べて、二分探索の計算量の少なさに驚きました。\nL08-Q1: データとは、データの種類、予測、発見、グルーピング\nL08-Q2: データ分析は身近であること、データを用いた予測、発見、グルーピングのやり方\nL08-Q3: 特にないです\nL08-Q4: 特にないです\nL08-Q5: データ分析はもっと専門的な知識を必要とすると思っていたので、こんなにも身近であることに驚きました。\nL09-Q1: 人工知能とは、人工知能を用いたビジネス、機械学習、今の人工知能にできないこと\nL09-Q2: 人工知能は思っている以上に万能ではないこと、人工知能を利用したビジネスの詳細\nL09-Q3: オープン戦略のあたりがまだ曖昧です\nL09-Q4: NaN\nL09-Q5: 人間の脳がいかに優れているかを実感しました。また、顧客監視のような人工知能を使ったビジネスの中にも知らないものがあったので、新しい知識を身に着けることができてよかったです。\nL10-Q1: 非構造データ(言語、画像、音声)、パターン認識とその応用\nL10-Q2: 非構造データとは何か、画像はベクトルで表せること、パターン認識とは何か、パターン認識の応用\nL10-Q3: とくにないです\nL10-Q4: NaN\nL10-Q5: 今、線形代数を履修しているので、ベクトル=画像で気を安らげたいと思います。また、深層ニューラルネットワークによるパターン認識が面白いと思いました。\nL11-Q1: データ収集、全数調査、標本調査、個人情報、オープンデータ、著作権\nL11-Q2: データ収集の主なやりかた、全数調査と標本調査のメリット・デメリット、個人情報の扱い方\nL11-Q3: オープンデータのところがまだ少し微妙です。定義はなんとなく理解できましたが、目的の一つである「透明性、信頼性の向上」がまだよく分からないです。\nL11-Q4: NaN\nL11-Q5: 個人情報の部分はサイバーセキュリティでやったところと重なっていたのですぐに理解ができました。また、メディアの街頭インタビューのような標本選択バイアスに惑わされないように気をつけようと思いました。\nL12-Q1: ベクトル、距離、類似度、それらの種類や応用\nL12-Q2: ベクトルとは何か、ベクトルを用いたデータ分析のやり方、距離の種類、距離や類似度の応用\nL12-Q3: max距離の使い方とコサイン類似度が微妙です\nL12-Q4: NaN\nL12-Q5: 距離と聞くと長さを表す単位(kmやm)が思いつくが、データ解析においても距離を使うのが新鮮で面白かった。\nL13-Q1: データの可視化、そのいろいろなやり方\nL13-Q2: 棒グラフや折れ線グラフなど、データの可視化の手法について、データの可視化の利点\nL13-Q3: 多次元データの可視化\nL13-Q4: NaN\nL13-Q5: パイチャートやヒートマップなど、初めて知ったデータの表し方があったので、面白かったです。データの可視化をする際には、どのやり方でするのがよいか、だけでなく、軸の数字や点の配置など、考えなければならないことがたくさんあるんだなと感じました。\nL14-Q1: 相関、分散、相関係数、統計的検定、画像処理、フィルタ処理、エッジ抽出\nL14-Q2: 相関係数の求め方、相関や分散や統計的検定の特徴\nL14-Q3: 微分フィルタ、ソーベルフィルタ\nL14-Q4: NaN\nL14-Q5: 高校の数学でやったところが多かったので、懐かしい気分になりました。フィルタ処理のところが難しかったです。\nL15-Q1: 画像処理の補足、期末テスト\nL15-Q2: ラプラシアンフィルタについて\nL15-Q3: NaN\nL15-Q4: NaN\nL15-Q5: 期末テストは結構時間がギリギリでした。説明をする記述問題が自信ないです。'}

# %%
for fold, (tr_idx, va_idx) in enumerate(
    gkf.split(X=np.zeros(len(data)), groups=groups)
):
    pp.pprint(f"{fold + 1}th fold ...")
    #  --- train ------------------------------------------
    train_ds = Subset(data, tr_idx)
    # --- valid ---------------------------------------------
    valid_ds = Subset(data, va_idx)

    pp.pprint(f"train size :: {train_ds.__len__()}")
    pp.pprint(f"valid size :: {valid_ds.__len__()}")

    print("=" * 30)
    print("Dataset sample")
    print("=" * 30)

    print("train::")
    print(train_ds.__getitem__(idx))

    print("valid::")
    print(train_ds.__getitem__(idx))

    loader = DataLoader(
        train_ds,
        batch_size=4,
        shuffle=False,
        collate_fn=train_collator,
    )

    print("DataLoader Sample::")
    batch = next(iter(loader))
    input_text = tokenizer.batch_decode(batch["input_ids"], skip_special_tokens=True)
    print(input_text)

    # fig = plot_fold_split_plotly(
    #     n_samples=len(data),
    #     train_idx=tr_idx,
    #     valid_idx=va_idx,
    #     title=f"{fold}‑th Fold"
    # )
    # fig.show()

    print("=" * 30)
    # pp.pprint(f"train sample (idx=1) :: {train_ds.__getitem__(1)}")
    # pp.pprint(f"valid sample (idx=1) :: {valid_ds.__getitem__(1)}")
# Out:
# 2025-07-18 15:34:40,072 : src.util : INFO : 599 : Tokenization Done
# '1th fold ...'
# 'train size :: 301'
# 'valid size :: 76'
# ==============================
# Dataset sample
# ==============================
# train::
# {'userid': 'C-2021-1_U37', 'labels': 1, 'grades': 'B', 'input_text': 'L01-Q1: 情報科学とは何か、どのように伝達するのか、また、これまでどのように情報が発達してきたか。\nL01-Q2: 情報の伝達方法は、原理的には今も昔も原理的には変わっておらず、伝えたいものを符号化して簡潔にしていることが分かった。\nL01-Q3: モールス信号についてまだよく知らないので演習をしたい。\nL01-Q4: NaN\nL01-Q5: はじめての情報科学の授業で、高校では習わなかったような歴史も知れて興味深かった。\nL02-Q1: 符号化した情報をできるだけ簡潔に復号するために確率の計算を用いてどの方法が最適であるかを調べる\nL02-Q2: 一意に戻せる情報とそうでないものの表現方法の違い\nL02-Q3: エントロピーについて\nL02-Q4: NaN\nL02-Q5: はじめは理解できていたがだんだん頭が混乱してきたのでまた復習をしたい\nL03-Q1: エントロピーは情報のあいまいさ\nL03-Q2: エントロピーや期待値の計算方法\nL03-Q3: 条件付き確率の計算\nL03-Q4: NaN\nL03-Q5: 何度も復習して理解を深めていきたい\nL04-Q1: 長さの等しいふたつのビット列に対して誤りを検出するハミング距離について\nL04-Q2: コンピュータが自動で訂正してくれること\nL04-Q3: ハミング距離の計算方法\nL04-Q4: NaN\nL04-Q5: まだ理解できていないところがあるので、復習をしたい\nL05-Q1: アルゴリズムの定義と計算\nL05-Q2: 根付き木の本質的な意味\nL05-Q3: 計算方法がまだあいまい\nL05-Q4: NaN\nL05-Q5: 本格的に理論的な話から実践的な話になってきたので使いこなせるようになりたい。 はじめ先生の音声が聞こえず何度か入退室してしまいましたすみません。\nL06-Q1: ユーグリットの互除法。バブルソート、選択ソートの計算方法の違い\nL06-Q2: 単純に計算しようとすると莫大な時間がかかる計算でも、バブルアルゴリズムを用いることによって大幅に時間を短縮することができる\nL06-Q3: まだ計算方法があいまいなので復習をしたい\nL06-Q4: NaN\nL06-Q5: 演習問題も何度も解きなおして理解を深めたい\nL07-Q1: 再帰的なアルゴリズムであるマージソートについて、また線形探索よりも圧倒的に早く計算できる2分探索について\nL07-Q2: 2分探索について、それぞれのステップで探索する範囲が1/2以下になる\nL07-Q3: logの計算\nL07-Q4: NaN\nL07-Q5: まだ理解できていないところもあるので復習をしたい\nL08-Q1: データサイエンス入門\nL08-Q2: あらかじめグループが決まっていないものについて類似性に基づいてクラスタリングできること\nL08-Q3: 質的データがどのようなものなのか\nL08-Q4: NaN\nL08-Q5: 今までデータの分析などは難しそうで自分には関係ないと思っていたが、身近なところで自分もデータを分析していたことが分かった\nL09-Q1: 現在の人工知能にできること、できないこと\nL09-Q2: 人工知能が学習しながら傾向をつかんでいくことがビジネスに応用されていること\nL09-Q3: 特にありません\nL09-Q4: NaN\nL09-Q5: 身近なところにあるAIがどういう仕組みなのかが分かった\nL10-Q1: AIは非構造データをどのように認識しているのか\nL10-Q2: 画像データや音声データなど、あいまいなものでもAIは学習を積極的に進めることでだんだん認識できるようになる\nL10-Q3: 特にありません\nL10-Q4: NaN\nL10-Q5: iPhoneでも、自分の顔写真を認識してアルバムを作ってくれたりしていた理由を学ぶことができて楽しかった\nL11-Q1: データの収集方法、そのメリット・デメリット\nL11-Q2: それぞれのデータの抽出方法の利点や弱点の理解\nL11-Q3: 特になし\nL11-Q4: NaN\nL11-Q5: 街頭アンケート調査は無作為抽出だと思っていたが、リポーターが恣意的に人を選んでいることや時間帯、報道の仕方によって人々に与える印象を操作できてしまうため、うのみにするのは危険だと思った。\nL12-Q1: データのベクトルとはどういうことか\nL12-Q2: 多次元ベクトルとしてデータを表現することによってデータの特徴について表現することができるということ\nL12-Q3: やはり線形代数がどのようにかかわってくるのかが分からなかったので線形代数の授業もより理解できるようになりたいです。\nL12-Q4: NaN\nL12-Q5: 感性語からロゴマークを作成するなど、「画像をベクトル化する」ことを可能にするデイープラーニングはあらゆる場面で活躍すると思いました。\nL13-Q1: データの可視化\nL13-Q2: それぞれのグラフのメリット、デメリット\nL13-Q3: NaN\nL13-Q4: NaN\nL13-Q5: グラフの軸の値によって直感的な判断を間違えてしまうこともあるということが分かったので、データを可視化する際には正しい方法で値をプロットしていきたいと思った\nL14-Q1: 相関と検定、画像\nL14-Q2: データの分布から2つの間にどんな関係があるかを調べることができること\nL14-Q3: 画像のフィルタ処理がまだよくわからなかったので、復習をしたいです\nL14-Q4: NaN\nL14-Q5: 相関係数などは高校数学よりも詳しく踏み込むことができてよかった\nL15-Q1: 前回の講義の補足、テスト\nL15-Q2: 昨日までにかなり集中してテスト勉強をしたので、勘で解いたところもあるけど、できました。\nL15-Q3: NaN\nL15-Q4: NaN\nL15-Q5: 15回授業分かりやすくて面白かったです。ありがとうございました。'}
# valid::
# {'userid': 'C-2021-1_U37', 'labels': 1, 'grades': 'B', 'input_text': 'L01-Q1: 情報科学とは何か、どのように伝達するのか、また、これまでどのように情報が発達してきたか。\nL01-Q2: 情報の伝達方法は、原理的には今も昔も原理的には変わっておらず、伝えたいものを符号化して簡潔にしていることが分かった。\nL01-Q3: モールス信号についてまだよく知らないので演習をしたい。\nL01-Q4: NaN\nL01-Q5: はじめての情報科学の授業で、高校では習わなかったような歴史も知れて興味深かった。\nL02-Q1: 符号化した情報をできるだけ簡潔に復号するために確率の計算を用いてどの方法が最適であるかを調べる\nL02-Q2: 一意に戻せる情報とそうでないものの表現方法の違い\nL02-Q3: エントロピーについて\nL02-Q4: NaN\nL02-Q5: はじめは理解できていたがだんだん頭が混乱してきたのでまた復習をしたい\nL03-Q1: エントロピーは情報のあいまいさ\nL03-Q2: エントロピーや期待値の計算方法\nL03-Q3: 条件付き確率の計算\nL03-Q4: NaN\nL03-Q5: 何度も復習して理解を深めていきたい\nL04-Q1: 長さの等しいふたつのビット列に対して誤りを検出するハミング距離について\nL04-Q2: コンピュータが自動で訂正してくれること\nL04-Q3: ハミング距離の計算方法\nL04-Q4: NaN\nL04-Q5: まだ理解できていないところがあるので、復習をしたい\nL05-Q1: アルゴリズムの定義と計算\nL05-Q2: 根付き木の本質的な意味\nL05-Q3: 計算方法がまだあいまい\nL05-Q4: NaN\nL05-Q5: 本格的に理論的な話から実践的な話になってきたので使いこなせるようになりたい。 はじめ先生の音声が聞こえず何度か入退室してしまいましたすみません。\nL06-Q1: ユーグリットの互除法。バブルソート、選択ソートの計算方法の違い\nL06-Q2: 単純に計算しようとすると莫大な時間がかかる計算でも、バブルアルゴリズムを用いることによって大幅に時間を短縮することができる\nL06-Q3: まだ計算方法があいまいなので復習をしたい\nL06-Q4: NaN\nL06-Q5: 演習問題も何度も解きなおして理解を深めたい\nL07-Q1: 再帰的なアルゴリズムであるマージソートについて、また線形探索よりも圧倒的に早く計算できる2分探索について\nL07-Q2: 2分探索について、それぞれのステップで探索する範囲が1/2以下になる\nL07-Q3: logの計算\nL07-Q4: NaN\nL07-Q5: まだ理解できていないところもあるので復習をしたい\nL08-Q1: データサイエンス入門\nL08-Q2: あらかじめグループが決まっていないものについて類似性に基づいてクラスタリングできること\nL08-Q3: 質的データがどのようなものなのか\nL08-Q4: NaN\nL08-Q5: 今までデータの分析などは難しそうで自分には関係ないと思っていたが、身近なところで自分もデータを分析していたことが分かった\nL09-Q1: 現在の人工知能にできること、できないこと\nL09-Q2: 人工知能が学習しながら傾向をつかんでいくことがビジネスに応用されていること\nL09-Q3: 特にありません\nL09-Q4: NaN\nL09-Q5: 身近なところにあるAIがどういう仕組みなのかが分かった\nL10-Q1: AIは非構造データをどのように認識しているのか\nL10-Q2: 画像データや音声データなど、あいまいなものでもAIは学習を積極的に進めることでだんだん認識できるようになる\nL10-Q3: 特にありません\nL10-Q4: NaN\nL10-Q5: iPhoneでも、自分の顔写真を認識してアルバムを作ってくれたりしていた理由を学ぶことができて楽しかった\nL11-Q1: データの収集方法、そのメリット・デメリット\nL11-Q2: それぞれのデータの抽出方法の利点や弱点の理解\nL11-Q3: 特になし\nL11-Q4: NaN\nL11-Q5: 街頭アンケート調査は無作為抽出だと思っていたが、リポーターが恣意的に人を選んでいることや時間帯、報道の仕方によって人々に与える印象を操作できてしまうため、うのみにするのは危険だと思った。\nL12-Q1: データのベクトルとはどういうことか\nL12-Q2: 多次元ベクトルとしてデータを表現することによってデータの特徴について表現することができるということ\nL12-Q3: やはり線形代数がどのようにかかわってくるのかが分からなかったので線形代数の授業もより理解できるようになりたいです。\nL12-Q4: NaN\nL12-Q5: 感性語からロゴマークを作成するなど、「画像をベクトル化する」ことを可能にするデイープラーニングはあらゆる場面で活躍すると思いました。\nL13-Q1: データの可視化\nL13-Q2: それぞれのグラフのメリット、デメリット\nL13-Q3: NaN\nL13-Q4: NaN\nL13-Q5: グラフの軸の値によって直感的な判断を間違えてしまうこともあるということが分かったので、データを可視化する際には正しい方法で値をプロットしていきたいと思った\nL14-Q1: 相関と検定、画像\nL14-Q2: データの分布から2つの間にどんな関係があるかを調べることができること\nL14-Q3: 画像のフィルタ処理がまだよくわからなかったので、復習をしたいです\nL14-Q4: NaN\nL14-Q5: 相関係数などは高校数学よりも詳しく踏み込むことができてよかった\nL15-Q1: 前回の講義の補足、テスト\nL15-Q2: 昨日までにかなり集中してテスト勉強をしたので、勘で解いたところもあるけど、できました。\nL15-Q3: NaN\nL15-Q4: NaN\nL15-Q5: 15回授業分かりやすくて面白かったです。ありがとうございました。'}
# DataLoader Sample::
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 31
#      23 loader = DataLoader(
#      24     train_ds,
#      25     batch_size=4,
#      26     shuffle=False,
#      27     collate_fn=train_collator,
#      28 )
#      30 print("DataLoader Sample::")
# ---> 31 batch = next(iter(loader))
#      32 input_text = tokenizer.batch_decode(batch["input_ids"], skip_special_tokens=True)
#      33 print(input_text)
#
# File /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File /home/masa1357/Dockerdata/gitfile/LLaVA-FT-datikz_Taiga/notebooks/../src/gradepred_data_forkfold.py:630, in GradePredictionCollator.__call__(self, features)
#     627     attn_mask = batch_ids.ne(self.tokenizer.pad_token_id).long()
#     629 else:
# --> 630     batch_ids = pad_sequence(
#     631         input_ids, batch_first=True, padding_value=self.tokenizer.pad_token_id
#     632     )
#     633     batch_lbl = pad_sequence(labels, batch_first=True, padding_value=-100)
#     634     attn_mask = batch_ids.ne(self.tokenizer.pad_token_id).long()
#
# File /usr/local/lib/python3.10/dist-packages/torch/nn/utils/rnn.py:481, in pad_sequence(sequences, batch_first, padding_value, padding_side)
#     477         sequences = sequences.unbind(0)  # type: ignore[assignment]
#     479 # assuming trailing dimensions and type of all the Tensors
#     480 # in sequences are same and fetching those from sequences[0]
# --> 481 return torch._C._nn.pad_sequence(
#     482     sequences, batch_first, padding_value, padding_side  # type: ignore[arg-type]
#     483 )
#
# TypeError: pad_sequence(): argument 'padding_value' (position 3) must be float, not NoneType

# %%
# 単文データの場合
data.reset()
data.unzip()
groups = np.array([data[i]["userid"] for i in range(len(data))])
print(len(groups))
gkf = GroupKFold(n_splits=5)
# Out:
# 28275

# %%
for fold, (tr_idx, va_idx) in enumerate(gkf.split(
        X=np.zeros(len(data)), groups=groups)):
    pp.pprint(f"{fold + 1}th fold ...")
    #  --- train ------------------------------------------
    train_ds = Subset(data, tr_idx)

    # --- valid ---------------------------------------------
    valid_ds   = Subset(data, va_idx)

    pp.pprint(f"train size :: {train_ds.__len__()}")
    pp.pprint(f"valid size :: {valid_ds.__len__()}")

    print("=" * 30)
    fig = plot_fold_split_plotly(
        n_samples=len(data),
        train_idx=tr_idx,
        valid_idx=va_idx,
        title=f"{fold}‑th Fold"
    )
    # fig.show(config=dict(staticPlot=True))


    print("=" * 30)
    # pp.pprint(f"train sample (idx=1) :: {train_ds.__getitem__(1)}")
    # pp.pprint(f"valid sample (idx=1) :: {valid_ds.__getitem__(1)}")
# Out:
# '1th fold ...'
# 'train size :: 22575'
# 'valid size :: 5700'
# ==============================
# ==============================
# '2th fold ...'
# 'train size :: 22575'
# 'valid size :: 5700'
# ==============================
# ==============================
# '3th fold ...'
# 'train size :: 22650'
# 'valid size :: 5625'
# ==============================
# ==============================
# '4th fold ...'
# 'train size :: 22650'
# 'valid size :: 5625'
# ==============================
# ==============================
# '5th fold ...'
# 'train size :: 22650'
# 'valid size :: 5625'
# ==============================
# ==============================

# %%
# 拡張データを外部から定義
ext_ds = ext_GPDataset(
    dataset_path=DATA_PATH
)
ext_ds.__len__()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 2
#       1 # 拡張データを外部から定義
# ----> 2 ext_ds = ext_GPDataset(
#       3     dataset_path=DATA_PATH
#       4 )
#       5 ext_ds.__len__()
#
# File /home/masa1357/Dockerdata/gitfile/LLaVA-FT-datikz_Taiga/notebooks/../src/gradepred_data_forkfold.py:483, in ext_GPDataset.__init__(self, dataset_path)
#     481 self.dataset_path = dataset_path
#     482 self.dataset: list[dict[str, Any]] = []
# --> 483 self.extention()
#
# File /home/masa1357/Dockerdata/gitfile/LLaVA-FT-datikz_Taiga/notebooks/../src/gradepred_data_forkfold.py:170, in GradePredictionDataset.extention(self)
#     168 def extention(self):
#     169     # 学習用データセットに拡張データを追加
# --> 170     self.logger.info("use extention data...")
#     171     ext_df = pd.read_csv(Path(self.dataset_path) / "extdata.csv")
#     172     for _, row in ext_df.iterrows():
#     173         # 拡張データの行を追加
#     174
#     175         # raw["grade"]に，(0~4)のラベルが含まれている
#     176         # このとき，4:A, 3:B, 2:C, 1:D, 0:F に対応しているため，
#     177         # label : 4->0 , 3->1, 2->2, 1->3, 0->4と変換，
#
# AttributeError: 'ext_GPDataset' object has no attribute 'logger'

# %%
# 単文 + 拡張データの場合
for fold, (tr_idx, va_idx) in enumerate(gkf.split(
        X=np.zeros(len(data)), groups=groups)):
    pp.pprint(f"{fold + 1}th fold ...")
    #  --- train ------------------------------------------
    train_ds_tmp = Subset(data, tr_idx)
    train_ds = ConcatDataset([train_ds_tmp, ext_ds])
    # --- valid ---------------------------------------------
    valid_ds   = Subset(data, va_idx)

    pp.pprint(f"train size :: {train_ds.__len__()} ({train_ds_tmp.__len__()} + {ext_ds.__len__()})")
    pp.pprint(f"valid size :: {valid_ds.__len__()}")
# Out:
# '1th fold ...'
# 'train size :: 52575 (22575 + 30000)'
# 'valid size :: 5700'
# '2th fold ...'
# 'train size :: 52575 (22575 + 30000)'
# 'valid size :: 5700'
# '3th fold ...'
# 'train size :: 52650 (22650 + 30000)'
# 'valid size :: 5625'
# '4th fold ...'
# 'train size :: 52650 (22650 + 30000)'
# 'valid size :: 5625'
# '5th fold ...'
# 'train size :: 52650 (22650 + 30000)'
# 'valid size :: 5625'
